# %%
import pandas as pd

# %%
df = pd.read_csv('data/BOLSAFAMILIA/visdata3-download-11-05-2025 133427.csv', encoding='latin1')

# %%
df
# Out:
#       Código Unidade Territorial  UF  Referência  Total de Benefícios Básicos  \
# 0     150010          ABAETETUBA  PA        2008                        12404
# 1     150010          ABAETETUBA  PA        2016                        21586
# 2     150010          ABAETETUBA  PA        2015                        19325
# 3     150010          ABAETETUBA  PA        2014                        20707
# 4     150010          ABAETETUBA  PA        2012                        20719
# ...      ...                 ...  ..         ...                          ...
# 2577  150840            XINGUARA  PA        2016                         3166
# 2578  150840            XINGUARA  PA        2021                         3600
# 2579  150840            XINGUARA  PA        2006                         1607
# 2580  150840            XINGUARA  PA        2004                          710
# 2581  150840            XINGUARA  PA        2014                         3454
#
# ...
